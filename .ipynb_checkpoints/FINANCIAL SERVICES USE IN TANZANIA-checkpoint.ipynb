# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("training.csv",index_col = 0)

# %%
df.head()
# Out:
#       Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  Q8_3  ...  Q17  Q18  Q19  \
# ID                                                  ...
# 5086  98   2   3   1   1   2   2     0     0     0  ...   -1    4    4
# 1258  40   1   1   3   5   1   1     1     0     0  ...    4    1    4
# 331   18   2   4   6   3   2   1     0     0     0  ...   -1    1    1
# 6729  50   1   1   3   1   1   1     0     0     0  ...   -1    1    4
# 8671  34   1   1   1   1   2   1     0     1     0  ...   -1    1    4
#
#       Latitude  Longitude  mobile_money  savings  borrowing  insurance  \
# ID
# 5086 -4.460442  29.811396             0        0          0          0
# 1258 -6.176438  39.244871             1        1          1          0
# 331  -6.825702  37.652798             1        0          0          0
# 6729 -3.372049  35.808307             1        0          1          0
# 8671 -7.179645  31.039095             1        1          0          1
#
#       mobile_money_classification
# ID
# 5086                            0
# 1258                            3
# 331                             2
# 6729                            3
# 8671                            3
#
# [5 rows x 36 columns]

# %% [markdown]
# # Missing Data

# %% [markdown]
# # 1.Examine the dataset. Are there any missing observations or columns where the data do not seem valid?

# %%
#Finding missing observations

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7094 entries, 5086 to 3946
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Q1                           7094 non-null   int64
#  1   Q2                           7094 non-null   int64
#  2   Q3                           7094 non-null   int64
#  3   Q4                           7094 non-null   int64
#  4   Q5                           7094 non-null   int64
#  5   Q6                           7094 non-null   int64
#  6   Q7                           7094 non-null   int64
#  7   Q8_1                         7094 non-null   int64
#  8   Q8_2                         7094 non-null   int64
#  9   Q8_3                         7094 non-null   int64
#  10  Q8_4                         7094 non-null   int64
#  11  Q8_5                         7094 non-null   int64
#  12  Q8_6                         7094 non-null   int64
#  13  Q8_7                         7094 non-null   int64
#  14  Q8_8                         7094 non-null   int64
#  15  Q8_9                         7094 non-null   int64
#  16  Q8_10                        7094 non-null   int64
#  17  Q8_11                        7094 non-null   int64
#  18  Q9                           7094 non-null   int64
#  19  Q10                          7094 non-null   int64
#  20  Q11                          7094 non-null   int64
#  21  Q12                          7094 non-null   int64
#  22  Q13                          7094 non-null   int64
#  23  Q14                          7094 non-null   int64
#  24  Q15                          7094 non-null   int64
#  25  Q16                          7094 non-null   int64
#  26  Q17                          7094 non-null   int64
#  27  Q18                          7094 non-null   int64
#  28  Q19                          7094 non-null   int64
#  29  Latitude                     7094 non-null   float64
#  30  Longitude                    7094 non-null   float64
#  31  mobile_money                 7094 non-null   int64
#  32  savings                      7094 non-null   int64
#  33  borrowing                    7094 non-null   int64
#  34  insurance                    7094 non-null   int64
#  35  mobile_money_classification  7094 non-null   int64
# dtypes: float64(2), int64(34)
# memory usage: 2.0 MB

# %% [markdown]
# There are no missing values in this dataFrame

# %%
df.corr()
# Out:
#                                    Q1        Q2        Q3        Q4        Q5  \
# Q1                           1.000000 -0.052484 -0.161434 -0.329742 -0.362815
# Q2                          -0.052484  1.000000  0.011540 -0.117319  0.101568
# Q3                          -0.161434  0.011540  1.000000  0.152441  0.175220
# Q4                          -0.329742 -0.117319  0.152441  1.000000  0.239325
# Q5                          -0.362815  0.101568  0.175220  0.239325  1.000000
# Q6                          -0.094837  0.113456  0.105623 -0.066519  0.063709
# Q7                           0.081805  0.184709  0.024248 -0.314218 -0.071444
# Q8_1                        -0.064513 -0.084585  0.055995  0.317273  0.155615
# Q8_2                         0.140593 -0.082230 -0.231267 -0.207214 -0.249640
# Q8_3                        -0.045270 -0.016613 -0.001252  0.060460  0.034118
# Q8_4                        -0.103955 -0.122446 -0.002638 -0.058131  0.016023
# Q8_5                         0.070229 -0.022061 -0.023464  0.014948 -0.060587
# Q8_6                         0.003982  0.028630 -0.015368  0.005187  0.004440
# Q8_7                         0.111216 -0.037158 -0.029383  0.092979 -0.038134
# Q8_8                         0.176739  0.064654  0.039405 -0.106788 -0.059314
# Q8_9                         0.020956  0.223685  0.078998  0.020715  0.077742
# Q8_10                       -0.082531  0.127091  0.104814  0.040867  0.101173
# Q8_11                       -0.003190 -0.000313 -0.000295  0.006253  0.000154
# Q9                          -0.072472 -0.067837  0.077564  0.220392  0.142941
# Q10                          0.047705 -0.011089 -0.122117 -0.073027 -0.071959
# Q11                         -0.025507 -0.022300 -0.005806  0.054231  0.024357
# Q12                          0.139266  0.146774  0.013925 -0.328939 -0.122527
# Q13                         -0.133105 -0.134727 -0.019213  0.284576  0.100519
# Q14                          0.028583  0.050897 -0.031216 -0.229869 -0.052992
# Q15                         -0.015970 -0.057953  0.019579  0.187609  0.030195
# Q16                         -0.092381 -0.092590  0.015299  0.278449  0.116480
# Q17                         -0.012336 -0.048690 -0.019762  0.332095  0.100525
# Q18                          0.274705  0.143204 -0.021926 -0.565468 -0.111005
# Q19                          0.205274  0.133639 -0.153409 -0.632613 -0.164312
# Latitude                    -0.034037  0.007249  0.011082  0.030085  0.078872
# Longitude                    0.032342  0.005003  0.062576  0.125175  0.026917
# mobile_money                -0.130623 -0.131080  0.005213  0.335169  0.111421
# savings                     -0.070161 -0.083250 -0.046364  0.180151  0.025777
# borrowing                   -0.073142 -0.071918 -0.103094  0.116817  0.008769
# insurance                    0.107807  0.005720 -0.036101  0.109255 -0.039233
# mobile_money_classification -0.127881 -0.142522 -0.033330  0.337340  0.095937
#
#                                    Q6        Q7      Q8_1      Q8_2      Q8_3  \
# Q1                          -0.094837  0.081805 -0.064513  0.140593 -0.045270
# Q2                           0.113456  0.184709 -0.084585 -0.082230 -0.016613
# Q3                           0.105623  0.024248  0.055995 -0.231267 -0.001252
# Q4                          -0.066519 -0.314218  0.317273 -0.207214  0.060460
# Q5                           0.063709 -0.071444  0.155615 -0.249640  0.034118
# Q6                           1.000000  0.110981 -0.080841 -0.025799 -0.012043
# Q7                           0.110981  1.000000 -0.180690  0.020998 -0.104603
# Q8_1                        -0.080841 -0.180690  1.000000 -0.204222 -0.033977
# Q8_2                        -0.025799  0.020998 -0.204222  1.000000 -0.123099
# Q8_3                        -0.012043 -0.104603 -0.033977 -0.123099  1.000000
# Q8_4                         0.028112  0.031507 -0.142942 -0.128982 -0.114700
# Q8_5                        -0.037097 -0.040679  0.017111 -0.006694  0.025603
# Q8_6                         0.007921 -0.006380  0.015946  0.023575  0.035128
# Q8_7                        -0.053410 -0.048079 -0.009414 -0.039842 -0.008505
# Q8_8                         0.048295  0.083147 -0.035314 -0.001181 -0.016152
# Q8_9                         0.091389  0.063757 -0.069254 -0.195706 -0.054012
# Q8_10                        0.063310  0.094835 -0.063765 -0.323255 -0.061499
# Q8_11                       -0.027749 -0.028976 -0.009176 -0.038315 -0.008850
# Q9                          -0.057962 -0.144102  0.891379 -0.185014 -0.030722
# Q10                         -0.023774 -0.051326 -0.137407  0.661600 -0.081820
# Q11                         -0.013587 -0.092040 -0.021412 -0.091674  0.878385
# Q12                          0.108077  0.399238 -0.232056  0.031704 -0.111477
# Q13                         -0.091141 -0.363196  0.179461 -0.017572  0.092483
# Q14                          0.046238  0.351899 -0.081399  0.013134 -0.097639
# Q15                         -0.033287 -0.300849  0.063525  0.005071  0.076803
# Q16                         -0.105686 -0.333066  0.156740 -0.058047  0.046508
# Q17                         -0.117216 -0.260335  0.254515 -0.106688  0.076440
# Q18                          0.061508  0.322407 -0.121980  0.037181 -0.067968
# Q19                          0.060724  0.251968 -0.257012  0.149740 -0.059150
# Latitude                     0.009000 -0.029356  0.005512 -0.071891 -0.018020
# Longitude                   -0.018210 -0.142345  0.080664 -0.140558  0.049872
# mobile_money                -0.097172 -0.550930  0.172287 -0.034852  0.105190
# savings                     -0.121290 -0.194026  0.149281  0.089040  0.066319
# borrowing                   -0.025949 -0.143032  0.080230  0.084820  0.044574
# insurance                   -0.046139 -0.085194  0.169942  0.016211  0.002831
# mobile_money_classification -0.116153 -0.529444  0.185612  0.013485  0.108115
#
#                              ...       Q17       Q18       Q19  Latitude  \
# Q1                           ... -0.012336  0.274705  0.205274 -0.034037
# Q2                           ... -0.048690  0.143204  0.133639  0.007249
# Q3                           ... -0.019762 -0.021926 -0.153409  0.011082
# Q4                           ...  0.332095 -0.565468 -0.632613  0.030085
# Q5                           ...  0.100525 -0.111005 -0.164312  0.078872
# Q6                           ... -0.117216  0.061508  0.060724  0.009000
# Q7                           ... -0.260335  0.322407  0.251968 -0.029356
# Q8_1                         ...  0.254515 -0.121980 -0.257012  0.005512
# Q8_2                         ... -0.106688  0.037181  0.149740 -0.071891
# Q8_3                         ...  0.076440 -0.067968 -0.059150 -0.018020
# Q8_4                         ... -0.070732  0.005434  0.081470 -0.020684
# Q8_5                         ...  0.048853 -0.004995 -0.034230  0.016357
# Q8_6                         ...  0.018749 -0.012455 -0.000859  0.052446
# Q8_7                         ...  0.085882 -0.044175 -0.079863 -0.009839
# Q8_8                         ... -0.039653  0.119575  0.075968  0.000839
# Q8_9                         ...  0.008664  0.032853 -0.021386  0.077964
# Q8_10                        ... -0.036864  0.022948 -0.028876  0.030928
# Q8_11                        ...  0.012991 -0.022688 -0.010430  0.003616
# Q9                           ...  0.183894 -0.098178 -0.182669  0.006987
# Q10                          ...  0.035466 -0.013728  0.033466 -0.011117
# Q11                          ...  0.067525 -0.055400 -0.052816 -0.018132
# Q12                          ... -0.293605  0.269520  0.290128 -0.030489
# Q13                          ...  0.235524 -0.248117 -0.246574  0.027518
# Q14                          ... -0.200522  0.227837  0.204902 -0.034322
# Q15                          ...  0.146555 -0.198086 -0.163415  0.028937
# Q16                          ...  0.312016 -0.223137 -0.228278  0.031173
# Q17                          ...  1.000000 -0.178102 -0.285990 -0.006192
# Q18                          ... -0.178102  1.000000  0.414955  0.005698
# Q19                          ... -0.285990  0.414955  1.000000 -0.043996
# Latitude                     ... -0.006192  0.005698 -0.043996  1.000000
# Longitude                    ...  0.157324 -0.054358 -0.100944 -0.334305
# mobile_money                 ...  0.274002 -0.342803 -0.279599  0.021524
# savings                      ...  0.168943 -0.181674 -0.173167  0.047830
# borrowing                    ...  0.100910 -0.134655 -0.096460  0.063079
# insurance                    ...  0.128991 -0.022988 -0.104002 -0.037096
# mobile_money_classification  ...  0.281440 -0.345513 -0.287592  0.037078
#
#                              Longitude  mobile_money   savings  borrowing  \
# Q1                            0.032342     -0.130623 -0.070161  -0.073142
# Q2                            0.005003     -0.131080 -0.083250  -0.071918
# Q3                            0.062576      0.005213 -0.046364  -0.103094
# Q4                            0.125175      0.335169  0.180151   0.116817
# Q5                            0.026917      0.111421  0.025777   0.008769
# Q6                           -0.018210     -0.097172 -0.121290  -0.025949
# Q7                           -0.142345     -0.550930 -0.194026  -0.143032
# Q8_1                          0.080664      0.172287  0.149281   0.080230
# Q8_2                         -0.140558     -0.034852  0.089040   0.084820
# Q8_3                          0.049872      0.105190  0.066319   0.044574
# Q8_4                         -0.026770      0.000782 -0.011608   0.066232
# Q8_5                         -0.008586      0.023112  0.029464  -0.000013
# Q8_6                         -0.048683      0.021206  0.050394   0.042353
# Q8_7                          0.031521      0.037630  0.017640  -0.027677
# Q8_8                          0.010095     -0.079143 -0.015666  -0.033199
# Q8_9                          0.089772     -0.001588 -0.057715  -0.031603
# Q8_10                         0.019667     -0.064573 -0.133560  -0.095692
# Q8_11                        -0.013544      0.031980  0.014667   0.008823
# Q9                            0.066756      0.140642  0.112030   0.063664
# Q10                          -0.027797      0.038500  0.105118   0.093958
# Q11                           0.040098      0.098665  0.059508   0.055136
# Q12                          -0.059415     -0.555411 -0.248968  -0.189457
# Q13                           0.040838      0.522983  0.215475   0.176357
# Q14                          -0.065174     -0.623055 -0.154309  -0.178500
# Q15                           0.040791      0.575627  0.128656   0.163121
# Q16                           0.032671      0.526656  0.149506   0.124174
# Q17                           0.157324      0.274002  0.168943   0.100910
# Q18                          -0.054358     -0.342803 -0.181674  -0.134655
# Q19                          -0.100944     -0.279599 -0.173167  -0.096460
# Latitude                     -0.334305      0.021524  0.047830   0.063079
# Longitude                     1.000000      0.079229 -0.005700  -0.034959
# mobile_money                  0.079229      1.000000  0.244746   0.192710
# savings                      -0.005700      0.244746  1.000000   0.177876
# borrowing                    -0.034959      0.192710  0.177876   1.000000
# insurance                    -0.001026      0.108093  0.096908   0.041685
# mobile_money_classification   0.054828      0.927591  0.442081   0.385427
#
#                              insurance  mobile_money_classification
# Q1                            0.107807                    -0.127881
# Q2                            0.005720                    -0.142522
# Q3                           -0.036101                    -0.033330
# Q4                            0.109255                     0.337340
# Q5                           -0.039233                     0.095937
# Q6                           -0.046139                    -0.116153
# Q7                           -0.085194                    -0.529444
# Q8_1                          0.169942                     0.185612
# Q8_2                          0.016211                     0.013485
# Q8_3                          0.002831                     0.108115
# Q8_4                         -0.046559                     0.012045
# Q8_5                          0.031995                     0.021247
# Q8_6                         -0.000813                     0.028692
# Q8_7                          0.078940                     0.037219
# Q8_8                          0.091133                    -0.068852
# Q8_9                          0.013857                    -0.023255
# Q8_10                        -0.038801                    -0.112399
# Q8_11                        -0.003993                     0.029139
# Q9                            0.089075                     0.149957
# Q10                          -0.014314                     0.076411
# Q11                           0.013563                     0.103083
# Q12                          -0.109012                    -0.547857
# Q13                           0.094094                     0.512252
# Q14                          -0.095849                    -0.589793
# Q15                           0.087023                     0.542592
# Q16                           0.080898                     0.498239
# Q17                           0.128991                     0.281440
# Q18                          -0.022988                    -0.345513
# Q19                          -0.104002                    -0.287592
# Latitude                     -0.037096                     0.037078
# Longitude                    -0.001026                     0.054828
# mobile_money                  0.108093                     0.927591
# savings                       0.096908                     0.442081
# borrowing                     0.041685                     0.385427
# insurance                     1.000000                     0.198670
# mobile_money_classification   0.198670                     1.000000
#
# [36 rows x 36 columns]

# %% [markdown]
# # 2.Get basic descriptive statistics for the dataset.

# %% [markdown]
# Renaming columns of age,gender,maritual status,land ownership and income types

# %%
df.rename(columns = {
    "Q1": "Age",
    "Q2": "Gender",
    "Q3": "Maritual Status",
    "Q5": "Land Ownership", 
    "Q6": "Other land ownership", 
    "Q7": "Mobile Or Non mobile", 
    "Q8_1": "Salaries/Wages",
    "Q8_2": "Food Producer",
    "Q8_3": "Service Provider", 
    "Q8_4": "Parttime Occupation", 
    "Q8_5": "Rental Income", 
    "Q8_6":  "Investments", 
    "Q8_7": "Pension",
    "Q8_8": "Grant",
    "Q8_9": "Dependent On Others", 
    "Q8_10": "No Income",
    "Q8_11": "Other"}, inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Maritual Status', 'Q4', 'Land Ownership',
#        'Other land ownership', 'Mobile Or Non mobile', 'Salaries/Wages',
#        'Food Producer', 'Service Provider', 'Parttime Occupation',
#        'Rental Income', 'Investments', 'Pension', 'Grant',
#        'Dependent On Others', 'No Income', 'Other', 'Q9', 'Q10', 'Q11', 'Q12',
#        'Q13', 'Q14', 'Q15', 'Q16', 'Q17', 'Q18', 'Q19', 'Latitude',
#        'Longitude', 'mobile_money', 'savings', 'borrowing', 'insurance',
#        'mobile_money_classification'],
#       dtype='object')

# %% [markdown]
# Finding the basic descriptive statistics of the dataset.

# %%
df.describe()
# Out:
#                Age       Gender  Maritual Status           Q4  Land Ownership  \
# count  7094.000000  7094.000000      7094.000000  7094.000000     7094.000000
# mean     38.239498     1.559910         1.787426     3.060051        2.548915
# std      16.332148     0.496433         1.165160     1.557779        1.534257
# min      16.000000     1.000000         1.000000     1.000000        1.000000
# 25%      25.000000     1.000000         1.000000     2.000000        1.000000
# 50%      35.000000     2.000000         1.000000     3.000000        3.000000
# 75%      48.000000     2.000000         3.000000     3.000000        4.000000
# max     100.000000     2.000000         4.000000     8.000000        6.000000
#
#        Other land ownership  Mobile Or Non mobile  Salaries/Wages  \
# count           7094.000000           7094.000000     7094.000000
# mean               1.840569              1.397942        0.062165
# std                0.366103              0.489508        0.241472
# min                1.000000              1.000000        0.000000
# 25%                2.000000              1.000000        0.000000
# 50%                2.000000              1.000000        0.000000
# 75%                2.000000              2.000000        0.000000
# max                2.000000              2.000000        1.000000
#
#        Food Producer  Service Provider  ...          Q17          Q18  \
# count    7094.000000       7094.000000  ...  7094.000000  7094.000000
# mean        0.630110          0.058077  ...    -0.431914     1.860164
# std         0.482809          0.233906  ...     1.489879     1.351372
# min         0.000000          0.000000  ...    -1.000000     1.000000
# 25%         0.000000          0.000000  ...    -1.000000     1.000000
# 50%         1.000000          0.000000  ...    -1.000000     1.000000
# 75%         1.000000          0.000000  ...    -1.000000     4.000000
# max         1.000000          1.000000  ...     5.000000     5.000000
#
#                Q19     Latitude    Longitude  mobile_money      savings  \
# count  7094.000000  7094.000000  7094.000000   7094.000000  7094.000000
# mean      3.163378    -6.034378    35.354029      0.553989     0.461517
# std       1.317691     2.720888     2.899511      0.497112     0.498552
# min       1.000000   -11.467463    29.639578      0.000000     0.000000
# 25%       2.000000    -8.275387    32.935429      0.000000     0.000000
# 50%       4.000000    -6.087854    35.073326      1.000000     0.000000
# 75%       4.000000    -3.517053    38.351815      1.000000     1.000000
# max       5.000000    -1.084000    40.258744      1.000000     1.000000
#
#          borrowing    insurance  mobile_money_classification
# count  7094.000000  7094.000000                  7094.000000
# mean      0.432901     0.151255                     1.799267
# std       0.495512     0.358322                     1.196955
# min       0.000000     0.000000                     0.000000
# 25%       0.000000     0.000000                     1.000000
# 50%       0.000000     0.000000                     2.000000
# 75%       1.000000     0.000000                     3.000000
# max       1.000000     1.000000                     3.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# 7094 interviews were made in total.

# %% [markdown]
# Finding total number of people who were interviewed(male and female)

# %%
#Total of male and female

Male = df[df["Gender"] == 1]
Female = df[df["Gender"] == 2]

Male.describe()
Female.describe()
# Out:
#                Age  Gender  Maritual Status           Q4  Land Ownership  \
# count  3972.000000  3972.0      3972.000000  3972.000000     3972.000000
# mean     37.479607     2.0         1.799345     2.898036        2.687059
# std      16.084996     0.0         1.103220     1.520257        1.485938
# min      16.000000     2.0         1.000000     1.000000        1.000000
# 25%      25.000000     2.0         1.000000     2.000000        1.000000
# 50%      34.000000     2.0         1.000000     3.000000        3.000000
# 75%      46.000000     2.0         3.000000     3.000000        4.000000
# max     100.000000     2.0         4.000000     7.000000        6.000000
#
#        Other land ownership  Mobile Or Non mobile  Salaries/Wages  \
# count           3972.000000           3972.000000     3972.000000
# mean               1.877392              1.478097        0.044058
# std                0.328028              0.499583        0.205251
# min                1.000000              1.000000        0.000000
# 25%                2.000000              1.000000        0.000000
# 50%                2.000000              1.000000        0.000000
# 75%                2.000000              2.000000        0.000000
# max                2.000000              2.000000        1.000000
#
#        Food Producer  Service Provider  ...          Q17          Q18  \
# count    3972.000000       3972.000000  ...  3972.000000  3972.000000
# mean        0.594914          0.054632  ...    -0.496224     2.031722
# std         0.490970          0.227290  ...     1.392767     1.420433
# min         0.000000          0.000000  ...    -1.000000     1.000000
# 25%         0.000000          0.000000  ...    -1.000000     1.000000
# 50%         1.000000          0.000000  ...    -1.000000     1.000000
# 75%         1.000000          0.000000  ...    -1.000000     4.000000
# max         1.000000          1.000000  ...     5.000000     5.000000
#
#                Q19     Latitude    Longitude  mobile_money      savings  \
# count  3972.000000  3972.000000  3972.000000   3972.000000  3972.000000
# mean      3.319486    -6.016893    35.366889      0.496224     0.424723
# std       1.240382     2.734942     2.892068      0.500049     0.494363
# min       1.000000   -11.466611    29.639578      0.000000     0.000000
# 25%       2.000000    -8.240882    32.957542      0.000000     0.000000
# 50%       4.000000    -6.072129    35.073337      0.000000     0.000000
# 75%       4.000000    -3.487150    38.327971      1.000000     1.000000
# max       5.000000    -1.084000    40.258744      1.000000     1.000000
#
#          borrowing    insurance  mobile_money_classification
# count  3972.000000  3972.000000                  3972.000000
# mean      0.401309     0.153072                     1.648036
# std       0.490225     0.360102                     1.206876
# min       0.000000     0.000000                     0.000000
# 25%       0.000000     0.000000                     1.000000
# 50%       0.000000     0.000000                     1.000000
# 75%       1.000000     0.000000                     3.000000
# max       1.000000     1.000000                     3.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# Out of the 7094 interviews,there total number of males who were interviewed is 3122 and the total of females is 3972.

# %% [markdown]
# # 3.Create appropriate graphs to visually represent the relationship between financial services accessed (non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income.

# %% [markdown]
# Classifying the rows in the dataframe for non mobile money users,mobile money users,non mobile or other and both mobile money and other in a new column

# %%
Non_mobile_money_or_other = df[(df.mobile_money_classification == 0)]
Non_mobile_money = df[(df.mobile_money_classification == 1)]
Mobile_money_only = df[(df.mobile_money_classification == 2)]
Both_mobile_money_and_other = df[(df.mobile_money_classification == 3)]

Non_mobile_money_or_other
Non_mobile_money
Mobile_money_only
Both_mobile_money_and_other
# Out:
#       Age  Gender  Maritual Status  Q4  Land Ownership  Other land ownership  \
# ID
# 1258   40       1                1   3               5                     1
# 6729   50       1                1   3               1                     1
# 8671   34       1                1   1               1                     2
# 4886   31       2                1   3               1                     2
# 621    23       2                4   5               5                     2
# ...   ...     ...              ...  ..             ...                   ...
# 4860   36       2                2   3               5                     2
# 24     24       1                1   3               4                     2
# 5546   25       1                1   4               1                     2
# 881    32       1                1   6               3                     1
# 5416   28       2                1   3               1                     2
#
#       Mobile Or Non mobile  Salaries/Wages  Food Producer  Service Provider  \
# ID
# 1258                     1               1              0                 0
# 6729                     1               0              0                 0
# 8671                     1               0              1                 0
# 4886                     1               0              1                 0
# 621                      1               0              0                 1
# ...                    ...             ...            ...               ...
# 4860                     1               0              1                 0
# 24                       1               0              1                 0
# 5546                     1               0              1                 0
# 881                      1               0              1                 0
# 5416                     2               0              1                 0
#
#       ...  Q17  Q18  Q19   Latitude  Longitude  mobile_money  savings  \
# ID    ...
# 1258  ...    4    1    4  -6.176438  39.244871             1        1
# 6729  ...   -1    1    4  -3.372049  35.808307             1        0
# 8671  ...   -1    1    4  -7.179645  31.039095             1        1
# 4886  ...   -1    1    2  -8.089257  35.836415             1        1
# 621   ...    1    2    2  -8.916028  33.433904             1        1
# ...   ...  ...  ...  ...        ...        ...           ...      ...
# 4860  ...    1    1    1 -10.369741  38.759225             1        1
# 24    ...   -1    1    1  -6.616820  39.096398             1        1
# 5546  ...   -1    1    1  -1.329040  31.808420             1        1
# 881   ...   -1    1    1  -2.635156  32.945423             1        1
# 5416  ...   -1    1    4  -8.090712  35.836560             1        0
#
#       borrowing  insurance  mobile_money_classification
# ID
# 1258          1          0                            3
# 6729          1          0                            3
# 8671          0          1                            3
# 4886          1          1                            3
# 621           0          0                            3
# ...         ...        ...                          ...
# 4860          1          0                            3
# 24            0          0                            3
# 5546          1          0                            3
# 881           0          0                            3
# 5416          0          1                            3
#
# [3126 rows x 36 columns]

# %%
classification = []
for i in df["mobile_money_classification"]:
    if i == 0 or i == 1:
        classification.append("Non_mobile_money")
        
    else:
        classification.append("Mobile_money")
        
        
df["classification"] = classification

# %% [markdown]
# Maping for gender

# %%
gender = { 1: "Male", 2: "Female"}
df["Gender"] = df["Gender"].map(gender)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and gender

# %%
# Checking the gender of non mobile money,mobile money and both

_ = sns.catplot(x = "Gender",kind = "count", col = "classification", aspect=.8, data = df).set(xlabel = "Gender")
_ = sns.catplot(x = "Gender",kind = "count",aspect =.8, data = df).set(title = "Both", xlabel = "Gender")

# %% [markdown]
# From the graph it's clear that more femalesw were interviewed and there are more female who don't use mobile money.Although there number of male and females who use mobile money is more or less the same and there are more femeles who use both mobile money and other financial services than males.

# %% [markdown]
# Maping for Maritual Status

# %%
Married = df[df["Maritual Status"] == 1]
Divorced = df[df["Maritual Status"] == 2]
Widowed = df[df["Maritual Status"] == 3]
Single = df[df["Maritual Status"] == 4]


Maritual_Status = {1: "Married", 2: "Divorced", 3: "Widowed", 4:"Single"}
df["Maritual Status"] = df["Maritual Status"].map(Maritual_Status)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and maritual status

# %%
# Checking the maritual status of non mobile money,mobile money and both

_ = sns.catplot(x = "Maritual Status",kind = "count" , col = "classification" ,aspect=.8, data = df).set(xlabel = "Maritual Status")
_ = sns.catplot(x = "Maritual Status",kind = "count",aspect =.8, data = df).set(title = "Both" ,xlabel = "Maritual Status")

# %% [markdown]
# Looking at the graphs above I can see that a lot of the interviewed people were married hence they are the ones who have there highest count in all classifications.

# %% [markdown]
# Mapping for Land Ownership

# %%
Landowner = df[df["Land Ownership"] == 1]
Sharing_land = df[df["Land Ownership"] == 2]
Household_member_owns_land = df[df["Land Ownership"] == 3]
Renting = df[df["Land Ownership"] == 4]
Owns_no_land = df[df["Land Ownership"] == 5]
Unknown = df[df["Land Ownership"] == 6]

df["Land Ownership"] = df["Land Ownership"].map(Landownership)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and Land Ownership

# %%
_ = sns.catplot(y = "Land Ownership",kind = "count", col = "classification" ,aspect=.8, data = df).set(xlabel = "Land Ownership")
_ = sns.catplot(y = "Land Ownership",kind = "count",aspect =.8, data = df).set(title = "Both" ,xlabel = "Land Ownership")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-607d25facae8> in <module>
# ----> 1 _ = sns.catplot(y = "Land Ownership",kind = "count", col = "classification" ,aspect=.8, data = df).set(xlabel = "Land Ownership")
#       2 _ = sns.catplot(y = "Land Ownership",kind = "count",aspect =.8, data = df).set(title = "Both" ,xlabel = "Land Ownership")
#
# ~/.local/lib/python3.6/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3732     # so we need to define ``palette`` to get default behavior for the
#    3733     # categorical functions
# -> 3734     p.establish_colors(color, palette, 1)
#    3735     if kind != "point" or hue is not None:
#    3736         palette = p.colors
#
# ~/.local/lib/python3.6/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     314         # Determine the gray color to use for the lines framing the plot
#     315         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 316         lum = min(light_vals) * .6
#     317         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     318
#
# ValueError: min() arg is an empty sequence

# %% [markdown]
# Looking at the graphs it is clear that more people own land and alot of use mobile money,whiule a few use both mobile money and other financial services.

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and Age

# %%
_= sns.barplot(y = "Age",  x = "classification" , data = df).set(xlabel = "Mobile_money_classification")
_= sns.barplot(y = "Age",  x = "classification" , data = df).set(title = "Both", ylabel = "Age")

# %% [markdown]
# From our graph it is clear that older people dont use mobile money as compared to younger people.

# %% [markdown]
#  # 4.Create appropriate graphs to visually represent the relationship between how often mobile services are used and age, gender, marital status, land ownership and type of income.

# %% [markdown]
# Visualing data for the relationship between how often mobile services are used and Maritual Status.

# %%
df.rename(columns = { 
    "Q16": "Mobile Money Purchase", 
    "Q17": "Mobile Money Bills"
}, inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Maritual Status', 'Q4', 'Land Ownership',
#        'Other land ownership', 'Mobile Or Non mobile', 'Salaries/Wages',
#        'Food Producer', 'Service Provider', 'Parttime Occupation',
#        'Rental Income', 'Investments', 'Pension', 'Grant',
#        'Dependent On Others', 'No Income', 'Other', 'Q9', 'Q10', 'Q11', 'Q12',
#        'Q13', 'Q14', 'Q15', 'Mobile Money Purchase', 'Mobile Money Bills',
#        'Q18', 'Q19', 'Latitude', 'Longitude', 'mobile_money', 'savings',
#        'borrowing', 'insurance', 'mobile_money_classification',
#        'classification'],
#       dtype='object')

# %% [markdown]
# Maping for Mobile Money Purchase

# %%
mobile_money_purchase = { 
    -1 : "Not Applicable", 
    1 : "Never", 
    2 : "Daily", 
    3 : "Weekly", 
    4 : "Monthly", 
    5 : "Less Than Monthly"
}
df["Mobile Money Purchase"] = df["Mobile Money Purchase"].map(mobile_money_purchase)

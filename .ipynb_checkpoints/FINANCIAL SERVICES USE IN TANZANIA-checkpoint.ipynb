# %% [markdown]
# # Introduction

# %% [markdown]
# In this notebook,I analyzed and visualized data from the demographic information and what financial services are used by approximately 10,000 individuals across Tanzania.This data was extracted from the FSDT Finscope 2017 survey and prepared specifically for this challenge.Each individual was classified as mobile money only,monbile money with other services,non mobile money and non mobile money and other services.This was done to represent the relationship between financial services accessed and how often the mobile money services are used(non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("training.csv",index_col = 0)

# %%
df.head()
# Out:
#       Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  Q8_3  ...  Q17  Q18  Q19  \
# ID                                                  ...
# 5086  98   2   3   1   1   2   2     0     0     0  ...   -1    4    4
# 1258  40   1   1   3   5   1   1     1     0     0  ...    4    1    4
# 331   18   2   4   6   3   2   1     0     0     0  ...   -1    1    1
# 6729  50   1   1   3   1   1   1     0     0     0  ...   -1    1    4
# 8671  34   1   1   1   1   2   1     0     1     0  ...   -1    1    4
#
#       Latitude  Longitude  mobile_money  savings  borrowing  insurance  \
# ID
# 5086 -4.460442  29.811396             0        0          0          0
# 1258 -6.176438  39.244871             1        1          1          0
# 331  -6.825702  37.652798             1        0          0          0
# 6729 -3.372049  35.808307             1        0          1          0
# 8671 -7.179645  31.039095             1        1          0          1
#
#       mobile_money_classification
# ID
# 5086                            0
# 1258                            3
# 331                             2
# 6729                            3
# 8671                            3
#
# [5 rows x 36 columns]

# %% [markdown]
# Renaming columns of age,gender,maritual status,land ownership and income types

# %%
df.rename(columns = {
    "Q1": "Age",
    "Q2": "Gender",
    "Q3": "Maritual Status",
    "Q5": "Land Ownership", 
    "Q6": "Other land ownership", 
    "Q7": "Mobile Or Non mobile", 
    "Q8_1": "Salaries/Wages",
    "Q8_2": "Food Producer",
    "Q8_3": "Service Provider", 
    "Q8_4": "Parttime Occupation", 
    "Q8_5": "Rental Income", 
    "Q8_6":  "Investments", 
    "Q8_7": "Pension",
    "Q8_8": "Grant",
    "Q8_9": "Dependent On Others", 
    "Q8_10": "No Income",
    "Q8_11": "Other",
    "Q16": "Mobile Money Purchase", 
    "Q17": "Mobile Money Bills"
}, inplace = True)

# %% [markdown]
# Below I checked the data type and my colums to check if there's nothing I'm not expecting.

# %%
#Checking columns
df.columns

#Checking data types
df.dtypes
# Out:
# Age                              int64
# Gender                           int64
# Maritual Status                  int64
# Q4                               int64
# Land Ownership                   int64
# Other land ownership             int64
# Mobile Or Non mobile             int64
# Salaries/Wages                   int64
# Food Producer                    int64
# Service Provider                 int64
# Parttime Occupation              int64
# Rental Income                    int64
# Investments                      int64
# Pension                          int64
# Grant                            int64
# Dependent On Others              int64
# No Income                        int64
# Other                            int64
# Q9                               int64
# Q10                              int64
# Q11                              int64
# Q12                              int64
# Q13                              int64
# Q14                              int64
# Q15                              int64
# Mobile Money Purchase            int64
# Mobile Money Bills               int64
# Q18                              int64
# Q19                              int64
# Latitude                       float64
# Longitude                      float64
# mobile_money                     int64
# savings                          int64
# borrowing                        int64
# insurance                        int64
# mobile_money_classification      int64
# dtype: object

# %% [markdown]
# Now that I know the data types and which columns I wanna work with,I am gonna get rid of the columns that I do not need by droping all unneeded columns to make it easier to work with the needed dataframe.

# %%
df.drop(["Q4",
         "Q9",
         "Q10",
         "Q11",
         "Q12", 
         "Q13", 
         "Q14", 
         "Q15", 
         "Q18",
         "Q19",
         "Latitude",
         "Longitude"], axis=1 , inplace = True)
df
# Out:
#       Age  Gender  Maritual Status  Land Ownership  Other land ownership  \
# ID
# 5086   98       2                3               1                     2
# 1258   40       1                1               5                     1
# 331    18       2                4               3                     2
# 6729   50       1                1               1                     1
# 8671   34       1                1               1                     2
# ...   ...     ...              ...             ...                   ...
# 8378   57       2                3               1                     2
# 881    32       1                1               3                     1
# 6672   22       2                3               3                     2
# 5416   28       2                1               1                     2
# 3946   78       1                3               1                     2
#
#       Mobile Or Non mobile  Salaries/Wages  Food Producer  Service Provider  \
# ID
# 5086                     2               0              0                 0
# 1258                     1               1              0                 0
# 331                      1               0              0                 0
# 6729                     1               0              0                 0
# 8671                     1               0              1                 0
# ...                    ...             ...            ...               ...
# 8378                     2               0              1                 0
# 881                      1               0              1                 0
# 6672                     2               0              1                 0
# 5416                     2               0              1                 0
# 3946                     2               0              0                 0
#
#       Parttime Occupation  ...  Dependent On Others  No Income  Other  \
# ID                         ...
# 5086                    0  ...                    1          0      0
# 1258                    0  ...                    0          0      0
# 331                     0  ...                    1          0      0
# 6729                    1  ...                    0          0      0
# 8671                    0  ...                    0          0      0
# ...                   ...  ...                  ...        ...    ...
# 8378                    0  ...                    1          0      0
# 881                     0  ...                    0          0      0
# 6672                    1  ...                    0          0      0
# 5416                    1  ...                    0          0      0
# 3946                    1  ...                    0          0      0
#
#       Mobile Money Purchase  Mobile Money Bills  mobile_money  savings  \
# ID
# 5086                      1                  -1             0        0
# 1258                      4                   4             1        1
# 331                       1                  -1             1        0
# 6729                      4                  -1             1        0
# 8671                      1                  -1             1        1
# ...                     ...                 ...           ...      ...
# 8378                      1                  -1             0        1
# 881                       5                  -1             1        1
# 6672                      1                  -1             0        0
# 5416                      1                  -1             1        0
# 3946                      1                  -1             0        0
#
#       borrowing  insurance  mobile_money_classification
# ID
# 5086          0          0                            0
# 1258          1          0                            3
# 331           0          0                            2
# 6729          1          0                            3
# 8671          0          1                            3
# ...         ...        ...                          ...
# 8378          0          0                            1
# 881           0          0                            3
# 6672          0          0                            0
# 5416          0          1                            3
# 3946          0          0                            0
#
# [7094 rows x 24 columns]

# %% [markdown]
# # Missing Data

# %% [markdown]
# # 1.Examine the dataset. Are there any missing observations or columns where the data do not seem valid?

# %%
#Finding missing observations

df.isnull().values.any().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values in this dataFrame

# %% [markdown]
# Finding the basic descriptive statistics of the dataset.

# %%
df.describe()
# Out:
#                Age       Gender  Maritual Status  Land Ownership  \
# count  7094.000000  7094.000000      7094.000000     7094.000000
# mean     38.239498     1.559910         1.787426        2.548915
# std      16.332148     0.496433         1.165160        1.534257
# min      16.000000     1.000000         1.000000        1.000000
# 25%      25.000000     1.000000         1.000000        1.000000
# 50%      35.000000     2.000000         1.000000        3.000000
# 75%      48.000000     2.000000         3.000000        4.000000
# max     100.000000     2.000000         4.000000        6.000000
#
#        Other land ownership  Mobile Or Non mobile  Salaries/Wages  \
# count           7094.000000           7094.000000     7094.000000
# mean               1.840569              1.397942        0.062165
# std                0.366103              0.489508        0.241472
# min                1.000000              1.000000        0.000000
# 25%                2.000000              1.000000        0.000000
# 50%                2.000000              1.000000        0.000000
# 75%                2.000000              2.000000        0.000000
# max                2.000000              2.000000        1.000000
#
#        Food Producer  Service Provider  Parttime Occupation  ...  \
# count    7094.000000       7094.000000          7094.000000  ...
# mean        0.630110          0.058077             0.337327  ...
# std         0.482809          0.233906             0.472831  ...
# min         0.000000          0.000000             0.000000  ...
# 25%         0.000000          0.000000             0.000000  ...
# 50%         1.000000          0.000000             0.000000  ...
# 75%         1.000000          0.000000             1.000000  ...
# max         1.000000          1.000000             1.000000  ...
#
#        Dependent On Others    No Income        Other  Mobile Money Purchase  \
# count          7094.000000  7094.000000  7094.000000            7094.000000
# mean              0.156752     0.057795     0.001269               1.951508
# std               0.363593     0.233372     0.035598               1.580819
# min               0.000000     0.000000     0.000000               1.000000
# 25%               0.000000     0.000000     0.000000               1.000000
# 50%               0.000000     0.000000     0.000000               1.000000
# 75%               0.000000     0.000000     0.000000               3.000000
# max               1.000000     1.000000     1.000000               5.000000
#
#        Mobile Money Bills  mobile_money      savings    borrowing  \
# count         7094.000000   7094.000000  7094.000000  7094.000000
# mean            -0.431914      0.553989     0.461517     0.432901
# std              1.489879      0.497112     0.498552     0.495512
# min             -1.000000      0.000000     0.000000     0.000000
# 25%             -1.000000      0.000000     0.000000     0.000000
# 50%             -1.000000      1.000000     0.000000     0.000000
# 75%             -1.000000      1.000000     1.000000     1.000000
# max              5.000000      1.000000     1.000000     1.000000
#
#          insurance  mobile_money_classification
# count  7094.000000                  7094.000000
# mean      0.151255                     1.799267
# std       0.358322                     1.196955
# min       0.000000                     0.000000
# 25%       0.000000                     1.000000
# 50%       0.000000                     2.000000
# 75%       0.000000                     3.000000
# max       1.000000                     3.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# 7094 interviews were made in total.

# %% [markdown]
# Finding total number of people who were interviewed(male and female)

# %%
#Total of male and female

Male = df[df["Gender"] == 1]
Female = df[df["Gender"] == 2]

Male.describe()
Female.describe()
# Out:
#                Age  Gender  Maritual Status  Land Ownership  \
# count  3972.000000  3972.0      3972.000000     3972.000000
# mean     37.479607     2.0         1.799345        2.687059
# std      16.084996     0.0         1.103220        1.485938
# min      16.000000     2.0         1.000000        1.000000
# 25%      25.000000     2.0         1.000000        1.000000
# 50%      34.000000     2.0         1.000000        3.000000
# 75%      46.000000     2.0         3.000000        4.000000
# max     100.000000     2.0         4.000000        6.000000
#
#        Other land ownership  Mobile Or Non mobile  Salaries/Wages  \
# count           3972.000000           3972.000000     3972.000000
# mean               1.877392              1.478097        0.044058
# std                0.328028              0.499583        0.205251
# min                1.000000              1.000000        0.000000
# 25%                2.000000              1.000000        0.000000
# 50%                2.000000              1.000000        0.000000
# 75%                2.000000              2.000000        0.000000
# max                2.000000              2.000000        1.000000
#
#        Food Producer  Service Provider  Parttime Occupation  ...  \
# count    3972.000000       3972.000000          3972.000000  ...
# mean        0.594914          0.054632             0.286002  ...
# std         0.490970          0.227290             0.451947  ...
# min         0.000000          0.000000             0.000000  ...
# 25%         0.000000          0.000000             0.000000  ...
# 50%         1.000000          0.000000             0.000000  ...
# 75%         1.000000          0.000000             1.000000  ...
# max         1.000000          1.000000             1.000000  ...
#
#        Dependent On Others    No Income        Other  Mobile Money Purchase  \
# count          3972.000000  3972.000000  3972.000000            3972.000000
# mean              0.228852     0.084089     0.001259               1.821752
# std               0.420147     0.277556     0.035462               1.515122
# min               0.000000     0.000000     0.000000               1.000000
# 25%               0.000000     0.000000     0.000000               1.000000
# 50%               0.000000     0.000000     0.000000               1.000000
# 75%               0.000000     0.000000     0.000000               1.000000
# max               1.000000     1.000000     1.000000               5.000000
#
#        Mobile Money Bills  mobile_money      savings    borrowing  \
# count         3972.000000   3972.000000  3972.000000  3972.000000
# mean            -0.496224      0.496224     0.424723     0.401309
# std              1.392767      0.500049     0.494363     0.490225
# min             -1.000000      0.000000     0.000000     0.000000
# 25%             -1.000000      0.000000     0.000000     0.000000
# 50%             -1.000000      0.000000     0.000000     0.000000
# 75%             -1.000000      1.000000     1.000000     1.000000
# max              5.000000      1.000000     1.000000     1.000000
#
#          insurance  mobile_money_classification
# count  3972.000000                  3972.000000
# mean      0.153072                     1.648036
# std       0.360102                     1.206876
# min       0.000000                     0.000000
# 25%       0.000000                     1.000000
# 50%       0.000000                     1.000000
# 75%       0.000000                     3.000000
# max       1.000000                     3.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# Out of the 7094 interviews,there total number of males who were interviewed is 3122 and the total of females is 3972.

# %% [markdown]
# # 3.Create appropriate graphs to visually represent the relationship between financial services accessed (non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income.

# %% [markdown]
# Classifying the rows in the dataframe for non mobile money users,mobile money users,non mobile or other and both mobile money and other in a new column

# %%
Non_mobile_money_or_other = df[(df.mobile_money_classification == 0)]
Non_mobile_money = df[(df.mobile_money_classification == 1)]
Mobile_money_only = df[(df.mobile_money_classification == 2)]
Both_mobile_money_and_other = df[(df.mobile_money_classification == 3)]

Non_mobile_money_or_other
Non_mobile_money
Mobile_money_only
Both_mobile_money_and_other
# Out:
#       Age  Gender  Maritual Status  Land Ownership  Other land ownership  \
# ID
# 1258   40       1                1               5                     1
# 6729   50       1                1               1                     1
# 8671   34       1                1               1                     2
# 4886   31       2                1               1                     2
# 621    23       2                4               5                     2
# ...   ...     ...              ...             ...                   ...
# 4860   36       2                2               5                     2
# 24     24       1                1               4                     2
# 5546   25       1                1               1                     2
# 881    32       1                1               3                     1
# 5416   28       2                1               1                     2
#
#       Mobile Or Non mobile  Salaries/Wages  Food Producer  Service Provider  \
# ID
# 1258                     1               1              0                 0
# 6729                     1               0              0                 0
# 8671                     1               0              1                 0
# 4886                     1               0              1                 0
# 621                      1               0              0                 1
# ...                    ...             ...            ...               ...
# 4860                     1               0              1                 0
# 24                       1               0              1                 0
# 5546                     1               0              1                 0
# 881                      1               0              1                 0
# 5416                     2               0              1                 0
#
#       Parttime Occupation  ...  Dependent On Others  No Income  Other  \
# ID                         ...
# 1258                    0  ...                    0          0      0
# 6729                    1  ...                    0          0      0
# 8671                    0  ...                    0          0      0
# 4886                    0  ...                    0          0      0
# 621                     0  ...                    0          0      0
# ...                   ...  ...                  ...        ...    ...
# 4860                    1  ...                    0          0      0
# 24                      0  ...                    0          0      0
# 5546                    1  ...                    0          0      0
# 881                     0  ...                    0          0      0
# 5416                    1  ...                    0          0      0
#
#       Mobile Money Purchase  Mobile Money Bills  mobile_money  savings  \
# ID
# 1258                      4                   4             1        1
# 6729                      4                  -1             1        0
# 8671                      1                  -1             1        1
# 4886                      1                  -1             1        1
# 621                       5                   1             1        1
# ...                     ...                 ...           ...      ...
# 4860                      1                   1             1        1
# 24                        2                  -1             1        1
# 5546                      1                  -1             1        1
# 881                       5                  -1             1        1
# 5416                      1                  -1             1        0
#
#       borrowing  insurance  mobile_money_classification
# ID
# 1258          1          0                            3
# 6729          1          0                            3
# 8671          0          1                            3
# 4886          1          1                            3
# 621           0          0                            3
# ...         ...        ...                          ...
# 4860          1          0                            3
# 24            0          0                            3
# 5546          1          0                            3
# 881           0          0                            3
# 5416          0          1                            3
#
# [3126 rows x 24 columns]

# %%
classification = []
for i in df["mobile_money_classification"]:
    if i == 0 or i == 1:
        classification.append("Non_mobile_money")
        
    else:
        classification.append("Mobile_money")
        
        
df["classification"] = classification

# %% [markdown]
# Maping for gender

# %%
gender = { 1: "Male", 2: "Female"}
df["Gender"] = df["Gender"].map(gender)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and gender

# %%
# Checking the gender of non mobile money,mobile money and both

_ = sns.catplot(x = "Gender",kind = "count", col = "classification", aspect=.8, data = df).set(xlabel = "Gender")
_ = sns.catplot(x = "Gender",kind = "count",aspect =.8, data = df).set(title = "Both", xlabel = "Gender")

# %% [markdown]
# From the graph it's clear that more femalesw were interviewed and there are more female who don't use mobile money.Although there number of male and females who use mobile money is more or less the same and there are more femeles who use both mobile money and other financial services than males.

# %% [markdown]
# Maping for Maritual Status

# %%
Married = df[df["Maritual Status"] == 1]
Divorced = df[df["Maritual Status"] == 2]
Widowed = df[df["Maritual Status"] == 3]
Single = df[df["Maritual Status"] == 4]


Maritual_Status = {1: "Married", 2: "Divorced", 3: "Widowed", 4:"Single"}
df["Maritual Status"] = df["Maritual Status"].map(Maritual_Status)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and maritual status

# %%
# Checking the maritual status of non mobile money,mobile money and both

_ = sns.catplot(x = "Maritual Status",kind = "count" , col = "classification" ,aspect=.8, data = df).set(xlabel = "Maritual Status")
_ = sns.catplot(x = "Maritual Status",kind = "count",aspect =.8, data = df).set(title = "Both" ,xlabel = "Maritual Status")

# %% [markdown]
# Looking at the graphs above I can see that a lot of the interviewed people were married hence they are the ones who have there highest count in all classifications.

# %% [markdown]
# Mapping for Land Ownership

# %%
Landowner = df[df["Land Ownership"] == 1]
Sharing_land = df[df["Land Ownership"] == 2]
Household_member_owns_land = df[df["Land Ownership"] == 3]
Renting = df[df["Land Ownership"] == 4]
Owns_no_land = df[df["Land Ownership"] == 5]
Unknown = df[df["Land Ownership"] == 6]

Landownership = {1 : "Landowner", 2 : "Sharing_land", 3 : "Household_member_owns_land", 4 : "Renting", 5 : "Owns_no_land", 6 : "Unknown" }

df["Land Ownership"] = df["Land Ownership"].map(Landownership)

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and Land Ownership

# %%
_ = sns.catplot(y = "Land Ownership",kind = "count", col = "classification" ,aspect=.8, data = df).set(xlabel = "Land Ownership")
_ = sns.catplot(y = "Land Ownership",kind = "count",aspect =.8, data = df).set(title = "Both" ,xlabel = "Land Ownership")

# %% [markdown]
# Looking at the graphs it is clear that more people own land and alot of use mobile money,whiule a few use both mobile money and other financial services.

# %% [markdown]
# Visualising data for (non mobile money,mobile money and both) and Age

# %%
_= sns.barplot(y = "Age",  x = "classification" , data = df).set(xlabel = "Mobile_money_classification")
_= sns.barplot(y = "Age",  x = "classification" , data = df).set(title = "Both", ylabel = "Age")

# %% [markdown]
# From our graph it is clear that older people dont use mobile money as compared to younger people.

# %% [markdown]
#  # 4.Create appropriate graphs to visually represent the relationship between how often mobile services are used and age, gender, marital status, land ownership and type of income.

# %% [markdown]
# Visualing data for the relationship between how often mobile services are used and Maritual Status.

# %% [markdown]
# Maping for Mobile Money Purchase

# %%
mobile_money_purchase = { 
    -1 : "Not Applicable", 
    1 : "Never", 
    2 : "Daily", 
    3 : "Weekly", 
    4 : "Monthly", 
    5 : "Less Than Monthly"
}

df["Mobile Money Purchase"] = df["Mobile Money Purchase"].map(mobile_money_purchase)

# %% [markdown]
# Maping for Mobile Money Bills

# %%
mobile_money_bills = {
    -1 : "Not Applicable", 
    1 : "Never", 
    2 : "Daily", 
    3 : "Weekly", 
    4 : "Monthly", 
    5 : "Less Than Monthly"
}
df["Mobile Money Bills"] = df["Mobile Money Bills"].map(mobile_money_bills)
